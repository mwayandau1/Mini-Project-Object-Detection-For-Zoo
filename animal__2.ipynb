# %%
# !pip install ultralytics
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.134 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.2/78.2 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import Image, display

# %%
# !mkdir /content/datasets_5
# %cd /content/datasets_5

# !unzip /content/drive/MyDrive/Animals__2.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: train/images/78_png.rf.6248f82a1abbd50ef396bb5bf0a6bc81.jpg
#  extracting: train/images/78a07eec9ebedc24_jpg.rf.85ffc073fc4ffa8729a529346d555172.jpg
#  extracting: train/images/797b332d333d534a_jpg.rf.9c6e1bcc716f2bda2001814d0c8c1cb1.jpg
#  extracting: train/images/79_png.rf.7a792e757a33b0a99174335782416e19.jpg
#  extracting: train/images/7_png.rf.57158d5c4c9f26b3ed135acad4a8fa65.jpg
#  extracting: train/images/7c68d5eaff52efb5_jpg.rf.215ddb11caca17cf9814b5c5b36e2f9c.jpg
#  extracting: train/images/7cdd69f8258548de_jpg.rf.b82512844bb3fc08d00744078d5b90b1.jpg
#  extracting: train/images/7d0ec79acf799d82_jpg.rf.239a7a126e1ac3cb97c8bb2ea16e3fc6.jpg
#  extracting: train/images/7e643e2a4cc45336_jpg.rf.4db521d56ba221a06b90e7f57eb65497.jpg
#  extracting: train/images/7f3057abf3447f6c_jpg.rf.b2f9cd6817643a4300b7b37951765b62.jpg
#  extracting: train/images/7f6cfffb7776d18a_jpg.rf.596d44aeb1ac6da68fa4d0ed3e2b533f.jpg
# ...

# %%
# %cd /content/datasets_5
# !yolo task=detect mode=train model=yolov8l.pt data=/content/datasets_5/data.yaml epochs=100 imgsz=500 plots=True
# Out:
# /content/datasets_5
# ...
# 100% 83.7M/83.7M [00:00<00:00, 202MB/s]
# Ultralytics YOLOv8.0.134 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
